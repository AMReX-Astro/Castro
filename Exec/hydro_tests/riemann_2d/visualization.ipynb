# %%
import matplotlib.pyplot as plt
import numpy as np
import yt

# set matplotlib formatting to be the same as yt
plt.rcParams['font.size'] = 14
plt.rcParams['font.family'] = 'serif'
plt.rcParams['mathtext.fontset'] = 'stix'

# %%
ds = yt.load("plt_riemman2d_40000315")
# Out:
# yt : [INFO     ] 2021-07-01 17:59:11,200 Parameters: current_time              = 0.3
# yt : [INFO     ] 2021-07-01 17:59:11,201 Parameters: domain_dimensions         = [400 400   1]
# yt : [INFO     ] 2021-07-01 17:59:11,202 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2021-07-01 17:59:11,204 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
print([f for _,f in ds.field_list])
# Out:
# ['Gamma_1', 'MachNumber', 'StateErr_0', 'StateErr_1', 'StateErr_2', 'Temp', 'X(X)', 'abar', 'angular_momentum_x', 'angular_momentum_y', 'angular_momentum_z', 'circvel', 'density', 'divu', 'eint_E', 'eint_e', 'entropy', 'kineng', 'logden', 'magmom', 'magvel', 'magvort', 'pressure', 'radvel', 'rho_E', 'rho_X', 'rho_e', 'soundspeed', 'x_velocity', 'xmom', 'y_velocity', 'ymom', 'z_velocity', 'zmom']

# %%
fig = yt.SlicePlot(ds, 'z', 'pressure' )

fig.set_cmap(field='pressure', cmap='Blue-Red')
fig.save('riemman_2d_case3.png')

fig
# Out:
# yt : [INFO     ] 2021-07-01 18:05:18,081 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-01 18:05:18,082 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-01 18:05:18,083 xlim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-01 18:05:18,084 ylim = 0.000000 1.000000
# yt : [INFO     ] 2021-07-01 18:05:18,086 Making a fixed resolution buffer of (('boxlib', 'pressure')) 800 by 800
# yt : [INFO     ] 2021-07-01 18:05:18,318 Saving plot riemman_2d_case3.png
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
