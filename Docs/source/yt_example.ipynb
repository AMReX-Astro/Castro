# %%
import yt

# %%
# load data from file
ds = yt.load('../../Exec/hydro_tests/Sedov/sedov_2d_cyl_in_cart_plt00150/')
# Out:
# yt : [INFO     ] 2020-05-29 13:54:33,650 Parameters: current_time              = 0.1
# yt : [INFO     ] 2020-05-29 13:54:33,651 Parameters: domain_dimensions         = [32 32  1]
# yt : [INFO     ] 2020-05-29 13:54:33,652 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2020-05-29 13:54:33,652 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
# plot the density
fig = yt.SlicePlot(ds, 'z', 'density')
fig
# Out:
# yt : [INFO     ] 2020-05-29 13:54:34,036 xlim = 0.000000 1.000000
# yt : [INFO     ] 2020-05-29 13:54:34,037 ylim = 0.000000 1.000000
# yt : [INFO     ] 2020-05-29 13:54:34,038 xlim = 0.000000 1.000000
# yt : [INFO     ] 2020-05-29 13:54:34,038 ylim = 0.000000 1.000000
# yt : [INFO     ] 2020-05-29 13:54:34,039 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%%;max-height:100%%;" src="data:image/png;base64,..."><br>
